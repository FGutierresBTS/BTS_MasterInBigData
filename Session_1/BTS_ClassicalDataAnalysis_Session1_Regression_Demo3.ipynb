# %% [markdown]
# # Subject: Classical Data Analysis
#
# ## Session 1 - Regression
#
# ### Demo 3 -  Linear Regression with Quandl Integration
#
#
# Implementation of Python StatsModels package with Quandl integration to calculate the Linear regression with one variable.

# %% [markdown]
# # 1 - Quandl Integration

# %% [markdown]
# A recurring challenge with any quantitative analysis is the availability of good quality data. Luckily for us, Quandl https://www.quandl.com/ has taken on the data challenge and indexed millions of economics, financial, societal, and country specific datasets. That data is also available through a free API (Application Programming Interface) supported by the Quandl Python package (https://www.quandl.com/tools/python).

# %% [markdown]
# # 2 - Register in Quandl

# %% [markdown]
# Get your Username, Password and Access key. Explore the Quandl website.

# %% [markdown]
# # 3 - Installation

# %% [markdown]
# For instructions on installing Quandl for Python check out PyPi (https://docs.python.org/2/install/) or the Github page (https://github.com/quandl/quandl-python).

# %% [markdown]
# The installation process varies depending on your python version and system used. However in most cases the following should work. Execute the following Pip command from CMD (Windows):

# %% [markdown]
# ### pip install quandl

# %% [markdown]
# Alternatively on some systems python3 may use a different pip executable and may need to be installed via an alternate pip command. For example:

# %% [markdown]
# ### pip3 install quandl

# %% [markdown]
# # 4 - Retrieving Data

# %% [markdown]
# There are two methods for retrieving data in Python: the Quick method and the Detailed method. The latter is more suitable to application programming. Both methods work with Quandl's two types of data structures: time-series (dataset) data and non-time series (datatable).

# %% [markdown]
# Retrieving data can be achieved easily using the two methods quandl.get for datasets and quandl.get_table for datatables. In both cases we strongly recommend that you set your api key via:

# %%
import quandl
quandl.ApiConfig.api_key = 'wagAy5tFsmUZ84CH3Ng8' # A valid API key is required to retrieve data. Please check your API key and try again. You can find your API key under your account settings.

# %% [markdown]
# ## Datasets (Time-Series)

# %% [markdown]
# The following quick call can be used to retrieve a dataset:

# %%
import quandl
data1 = quandl.get('NSE/OIL')

# %% [markdown]
# This example finds all data points for the dataset NSE/OIL and stores (https://www.quandl.com/data/NSE/OIL) them in a pandas dataframe. You can then view the dataframe with data.head().

# %%
data1.head()
# Out:
#               Open    High     Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.0  1156.7  1090.0  1135.00  1141.20            19748012.0
# 2009-10-01  1102.0  1173.7  1102.0  1167.00  1166.35             3074254.0
# 2009-10-05  1152.0  1165.9  1136.6  1143.00  1140.55              919832.0
# 2009-10-06  1149.8  1157.2  1132.1  1143.30  1144.90              627957.0
# 2009-10-07  1153.8  1160.7  1140.0  1141.45  1141.60              698216.0
#
#             Turnover (Lacs)
# Date
# 2009-09-30        223877.07
# 2009-10-01         35463.78
# 2009-10-05         10581.13
# 2009-10-06          7185.90
# 2009-10-07          8032.98

# %% [markdown]
# Loading CSV data in Python with pandas.
#
# Use this API call to get data in CSV format: https://www.quandl.com/api/v3/datasets/NSE/OIL.csv?api_key=wagAy5tFsmUZ84CH3Ng8

# %%
import pandas as pd
data12=pd.read_csv("https://www.quandl.com/api/v3/datasets/NSE/OIL.csv?api_key=wagAy5tFsmUZ84CH3Ng8")
data12.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2017-10-03  353.00  356.90  348.85  354.50  354.75              689435.0
# 1  2017-09-29  345.95  354.95  340.10  353.65  353.65              861320.0
# 2  2017-09-28  349.90  354.95  335.80  344.70  348.30             2079490.0
# 3  2017-09-27  349.70  356.10  345.10  350.00  350.55             1493047.0
# 4  2017-09-26  334.00  350.00  332.60  349.70  349.35             1911979.0
#
#    Turnover (Lacs)
# 0          2432.93
# 1          3013.87
# 2          7185.88
# 3          5236.91
# 4          6593.90

# %% [markdown]
# Loading CSV data in Python with pandas using a file exported from Quandl.

# %%
import pandas as pd
data13=pd.read_csv("C:/Users/francisco.sacramento/Desktop/Master_Big_Data_Phyton/6_Exercices/Classical Data Analysis/NSE-OIL.csv")
data13.head()
# Out:
#          Date   Open    High     Low   Last   Close  Total Trade Quantity  \
# 0  2017-09-27  349.7  356.10  345.10  350.0  350.55             1493047.0
# 1  2017-09-26  334.0  350.00  332.60  349.7  349.35             1911979.0
# 2  2017-09-25  325.3  333.75  321.20  332.0  332.50              995497.0
# 3  2017-09-22  327.9  332.65  321.50  328.9  328.70             1428072.0
# 4  2017-09-21  328.0  330.20  322.05  326.4  328.30              769453.0
#
#    Turnover (Lacs)
# 0          5236.91
# 1          6593.90
# 2          3278.67
# 3          4686.54
# 4          2522.00

# %% [markdown]
# However in some cases is recommended applying filters to streamline the results. To do this you may want to specify some additional filters.

# %%
import quandl
data2 = quandl.get('NSE/OIL', start_date='2010-01-01', end_date='2014-01-01')

# %% [markdown]
# This revised query will find all data points annually for the dataset NSE/OIL between the year 2010 and 2014.

# %%
data2.head()
# Out:
#                Open    High      Low    Last    Close  Total Trade Quantity  \
# Date
# 2010-01-04  1259.90  1259.9  1235.00  1242.5  1240.30               41769.0
# 2010-01-05  1259.55  1265.0  1237.05  1249.9  1250.55              129799.0
# 2010-01-06  1255.10  1268.0  1242.50  1250.0  1248.80               63129.0
# 2010-01-07  1246.10  1255.0  1231.30  1241.5  1241.40               36209.0
# 2010-01-08  1248.90  1268.0  1230.00  1265.0  1262.95               64337.0
#
#             Turnover (Lacs)
# Date
# 2010-01-04           519.53
# 2010-01-05          1616.00
# 2010-01-06           790.45
# 2010-01-07           451.02
# 2010-01-08           807.72

# %% [markdown]
# ## Datatables

# %% [markdown]
# Datatables work similarly to datasets but provide more flexibility when it comes to filtering. For example a simple way to retrieve datatable information would be:

# %%
import quandl
data3 = quandl.get_table('ZACKS/FC')

# %%
data3.head()
# Out:
#      m_ticker ticker  comp_name comp_name_2 exchange currency_code  \
# None
# 0        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 1        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 2        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 3        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
# 4        AAPL   AAPL  APPLE INC  Apple Inc.     NSDQ           USD
#
#      per_end_date per_type per_code  per_fisc_year       ...         \
# None                                                     ...
# 0      2011-09-30        A     None           2011       ...
# 1      2012-09-30        A     None           2012       ...
# 2      2013-09-30        A     None           2013       ...
# 3      2014-09-30        A     None           2014       ...
# 4      2015-09-30        A     None           2015       ...
#
#       stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#       net_change_prop_plant_equip_qd comm_stock_div_paid_qd  \
# None
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                                NaN                    NaN
# 4                                NaN                    NaN
#
#      pref_stock_div_paid_qd  tot_comm_pref_stock_div_qd  wavg_shares_out  \
# None
# 0                      None                         NaN         6469.806
# 1                      None                         NaN         6543.726
# 2                      None                         NaN         6477.320
# 3                      None                         NaN         6085.572
# 4                      None                         NaN         5753.421
#
#       wavg_shares_out_diluted  eps_basic_net  eps_diluted_net
# None
# 0                    6556.515         4.0071           3.9543
# 1                    6617.483         6.3800           6.3100
# 2                    6521.634         5.7200           5.6800
# 3                    6122.663         6.4900           6.4500
# 4                    5793.069         9.2800           9.2200
#
# [5 rows x 249 columns]

# %% [markdown]
# This is the syntax for calling an entire table. Given the volume of data stored in datatables, this call will retrieve the first page of the ZACKS/FC datatable. You may turn on pagination to return more data by using:

# %%
import quandl
data4 = quandl.get_table('ZACKS/FC', paginate=True)

# %%
data4
# Out:
#      m_ticker ticker        comp_name              comp_name_2 exchange  \
# None
# 0        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 1        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 2        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 3        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 4        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 5        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 6        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 7        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 8        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 9        AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 10       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 11       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 12       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 13       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 14       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 15       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 16       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 17       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 18       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 19       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 20       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 21       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 22       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 23       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 24       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 25       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 26       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 27       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 28       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# 29       AAPL   AAPL        APPLE INC               Apple Inc.     NSDQ
# ...       ...    ...              ...                      ...      ...
# 940         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 941         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 942         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 943         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 944         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 945         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 946         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 947         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 948         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 949         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 950         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 951         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 952         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 953         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 954         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 955         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 956         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 957         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 958         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 959         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 960         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 961         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 962         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 963         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 964         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 965         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 966         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 967         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 968         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
# 969         J    XOM  EXXON MOBIL CRP  Exxon Mobil Corporation     NYSE
#
#      currency_code per_end_date per_type per_code  per_fisc_year  \
# None
# 0              USD   2011-09-30        A     None           2011
# 1              USD   2012-09-30        A     None           2012
# 2              USD   2013-09-30        A     None           2013
# 3              USD   2014-09-30        A     None           2014
# 4              USD   2015-09-30        A     None           2015
# 5              USD   2016-09-30        A     None           2016
# 6              USD   2011-03-31        Q     None           2011
# 7              USD   2011-06-30        Q     None           2011
# 8              USD   2011-09-30        Q     None           2011
# 9              USD   2011-12-31        Q     None           2012
# 10             USD   2012-03-31        Q     None           2012
# 11             USD   2012-06-30        Q     None           2012
# 12             USD   2012-09-30        Q     None           2012
# 13             USD   2012-12-31        Q     None           2013
# 14             USD   2013-03-31        Q     None           2013
# 15             USD   2013-06-30        Q     None           2013
# 16             USD   2013-09-30        Q     None           2013
# 17             USD   2013-12-31        Q     None           2014
# 18             USD   2014-03-31        Q     None           2014
# 19             USD   2014-06-30        Q     None           2014
# 20             USD   2014-09-30        Q     None           2014
# 21             USD   2014-12-31        Q     None           2015
# 22             USD   2015-03-31        Q     None           2015
# 23             USD   2015-06-30        Q     None           2015
# 24             USD   2015-09-30        Q     None           2015
# 25             USD   2015-12-31        Q     None           2016
# 26             USD   2016-03-31        Q     None           2016
# 27             USD   2016-06-30        Q     None           2016
# 28             USD   2016-09-30        Q     None           2016
# 29             USD   2016-12-31        Q     None           2017
# ...            ...          ...      ...      ...            ...
# 940            USD   2013-12-31        A     None           2013
# 941            USD   2014-12-31        A     None           2014
# 942            USD   2015-12-31        A     None           2015
# 943            USD   2016-12-31        A     None           2016
# 944            USD   2011-03-31        Q     None           2011
# 945            USD   2011-06-30        Q     None           2011
# 946            USD   2011-09-30        Q     None           2011
# 947            USD   2011-12-31        Q     None           2011
# 948            USD   2012-03-31        Q     None           2012
# 949            USD   2012-06-30        Q     None           2012
# 950            USD   2012-09-30        Q     None           2012
# 951            USD   2012-12-31        Q     None           2012
# 952            USD   2013-03-31        Q     None           2013
# 953            USD   2013-06-30        Q     None           2013
# 954            USD   2013-09-30        Q     None           2013
# 955            USD   2013-12-31        Q     None           2013
# 956            USD   2014-03-31        Q     None           2014
# 957            USD   2014-06-30        Q     None           2014
# 958            USD   2014-09-30        Q     None           2014
# 959            USD   2014-12-31        Q     None           2014
# 960            USD   2015-03-31        Q     None           2015
# 961            USD   2015-06-30        Q     None           2015
# 962            USD   2015-09-30        Q     None           2015
# 963            USD   2015-12-31        Q     None           2015
# 964            USD   2016-03-31        Q     None           2016
# 965            USD   2016-06-30        Q     None           2016
# 966            USD   2016-09-30        Q     None           2016
# 967            USD   2016-12-31        Q     None           2016
# 968            USD   2017-03-31        Q     None           2017
# 969            USD   2017-06-30        Q     None           2017
#
#            ...         stock_based_compsn_qd  cash_flow_oper_activity_qd  \
# None       ...
# 0          ...                           NaN                         NaN
# 1          ...                           NaN                         NaN
# 2          ...                           NaN                         NaN
# 3          ...                           NaN                         NaN
# 4          ...                           NaN                         NaN
# 5          ...                           NaN                         NaN
# 6          ...                         287.0                      6219.0
# 7          ...                         284.0                     11108.0
# 8          ...                         298.0                     10429.0
# 9          ...                         420.0                     17554.0
# 10         ...                         424.0                     13977.0
# 11         ...                         448.0                     10189.0
# 12         ...                         448.0                      9136.0
# 13         ...                         545.0                     23426.0
# 14         ...                         575.0                     12504.0
# 15         ...                         578.0                      7828.0
# 16         ...                         555.0                      9908.0
# 17         ...                         681.0                     22670.0
# 18         ...                         696.0                     13538.0
# 19         ...                         724.0                     10255.0
# 20         ...                         762.0                     13250.0
# 21         ...                         888.0                     33722.0
# 22         ...                         927.0                     19081.0
# 23         ...                         856.0                     14988.0
# 24         ...                         915.0                     13475.0
# 25         ...                        1078.0                     27463.0
# 26         ...                        1048.0                     11601.0
# 27         ...                        1054.0                     10634.0
# 28         ...                        1030.0                     16126.0
# 29         ...                        1256.0                     27056.0
# ...        ...                           ...                         ...
# 940        ...                           NaN                         NaN
# 941        ...                           NaN                         NaN
# 942        ...                           NaN                         NaN
# 943        ...                           NaN                         NaN
# 944        ...                           NaN                     16856.0
# 945        ...                           NaN                     12889.0
# 946        ...                           NaN                     14849.0
# 947        ...                           NaN                     10751.0
# 948        ...                           NaN                     19287.0
# 949        ...                           NaN                     10217.0
# 950        ...                           NaN                     13442.0
# 951        ...                           NaN                     13224.0
# 952        ...                           NaN                     13592.0
# 953        ...                           NaN                      7683.0
# 954        ...                           NaN                     13431.0
# 955        ...                           NaN                     10208.0
# 956        ...                           NaN                     15103.0
# 957        ...                           NaN                     10202.0
# 958        ...                           NaN                     12396.0
# 959        ...                           NaN                      7415.0
# 960        ...                           NaN                      7998.0
# 961        ...                           NaN                      8792.0
# 962        ...                           NaN                      9174.0
# 963        ...                           NaN                      4380.0
# 964        ...                           NaN                      4812.0
# 965        ...                           NaN                      4519.0
# 966        ...                           NaN                      5355.0
# 967        ...                           NaN                      7396.0
# 968        ...                           NaN                      8173.0
# 969        ...                           NaN                      6947.0
#
#       net_change_prop_plant_equip_qd comm_stock_div_paid_qd  \
# None
# 0                                NaN                    NaN
# 1                                NaN                    NaN
# 2                                NaN                    NaN
# 3                                NaN                    NaN
# 4                                NaN                    NaN
# 5                                NaN                    NaN
# 6                             -624.0                    NaN
# 7                             -777.0                    NaN
# 8                            -1645.0                    NaN
# 9                            -1321.0                    0.0
# 10                           -1457.0                    0.0
# 11                           -2056.0                    0.0
# 12                           -3461.0                -2488.0
# 13                           -2317.0                -2493.0
# 14                           -2008.0                -2491.0
# 15                           -1885.0                -2811.0
# 16                           -1955.0                -2769.0
# 17                           -1985.0                -2769.0
# 18                           -1382.0                -2661.0
# 19                           -2378.0                -2867.0
# 20                           -3826.0                -2829.0
# 21                           -3217.0                -2801.0
# 22                           -2369.0                -2743.0
# 23                           -2043.0                -3053.0
# 24                           -3618.0                -2964.0
# 25                           -3612.0                -2969.0
# 26                           -2336.0                -2902.0
# 27                           -2809.0                -3187.0
# 28                           -3977.0                -3092.0
# 29                           -3334.0                -3130.0
# ...                              ...                    ...
# 940                              NaN                    NaN
# 941                              NaN                    NaN
# 942                              NaN                    NaN
# 943                              NaN                    NaN
# 944                          -7051.0                -2283.0
# 945                          -7812.0                -2365.0
# 946                          -7478.0                -2389.0
# 947                          -8634.0                -2289.0
# 948                          -7843.0                -2317.0
# 949                          -8345.0                -2698.0
# 950                          -8026.0                -2772.0
# 951                         -10057.0                -2632.0
# 952                          -7494.0                -2666.0
# 953                          -8651.0                -2874.0
# 954                          -9098.0                -2810.0
# 955                          -8426.0                -2829.0
# 956                          -7328.0                -2790.0
# 957                          -8542.0                -3039.0
# 958                          -8198.0                -2987.0
# 959                          -8884.0                -3000.0
# 960                          -6844.0                -2950.0
# 961                          -7109.0                -3114.0
# 962                          -6401.0                -3099.0
# 963                          -6136.0                -3097.0
# 964                          -4601.0                -3096.0
# 965                          -4271.0                -3176.0
# 966                          -3404.0                -3170.0
# 967                          -3887.0                -3173.0
# 968                          -2890.0                -3178.0
# 969                          -3098.0                -3336.0
#
#      pref_stock_div_paid_qd  tot_comm_pref_stock_div_qd  wavg_shares_out  \
# None
# 0                      None                         NaN         6469.806
# 1                      None                         NaN         6543.726
# 2                      None                         NaN         6477.320
# 3                      None                         NaN         6085.572
# 4                      None                         NaN         5753.421
# 5                      None                         NaN         5470.820
# 6                      None                         NaN         6462.372
# 7                      None                         NaN         6482.756
# 8                      None                         NaN         6469.806
# 9                      None                         NaN         6517.287
# 10                     None                         NaN         6535.074
# 11                     None                         NaN         6556.172
# 12                     None                         NaN         6543.726
# 13                     None                     -2493.0         6572.412
# 14                     None                     -2491.0         6577.403
# 15                     None                     -2811.0         6430.323
# 16                     None                     -2769.0         6477.320
# 17                     None                     -2769.0         6272.504
# 18                     None                     -2661.0         6123.302
# 19                     None                     -2867.0         6012.635
# 20                     None                     -2829.0         6085.572
# 21                     None                     -2801.0         5843.082
# 22                     None                     -2743.0         5793.799
# 23                     None                     -3053.0         5729.886
# 24                     None                     -2964.0         5753.421
# 25                     None                     -2969.0         5558.930
# 26                     None                     -2902.0         5514.381
# 27                     None                     -3187.0         5443.058
# 28                     None                     -3092.0         5470.820
# 29                     None                     -3130.0         5298.661
# ...                     ...                         ...              ...
# 940                    None                         NaN         4419.000
# 941                    None                         NaN         4282.000
# 942                    None                         NaN         4196.000
# 943                    None                         NaN         4177.000
# 944                    None                     -2283.0         4963.000
# 945                    None                     -2365.0         4906.000
# 946                    None                     -2389.0         4839.000
# 947                    None                     -2289.0         4870.000
# 948                    None                     -2317.0         4715.000
# 949                    None                     -2698.0         4656.000
# 950                    None                     -2772.0         4597.000
# 951                    None                     -2632.0         4628.000
# 952                    None                     -2666.0         4485.000
# 953                    None                     -2874.0         4433.000
# 954                    None                     -2810.0         4395.000
# 955                    None                     -2829.0         4419.000
# 956                    None                     -2790.0         4328.000
# 957                    None                     -3039.0         4297.000
# 958                    None                     -2987.0         4267.000
# 959                    None                     -3000.0         4282.000
# 960                    None                     -2950.0         4211.000
# 961                    None                     -3114.0         4200.000
# 962                    None                     -3099.0         4190.000
# 963                    None                     -3097.0         4196.000
# 964                    None                     -3096.0         4178.000
# 965                    None                     -3176.0         4178.000
# 966                    None                     -3170.0         4178.000
# 967                    None                     -3173.0         4177.000
# 968                    None                     -3178.0         4223.000
# 969                    None                     -3336.0         4271.000
#
#       wavg_shares_out_diluted  eps_basic_net  eps_diluted_net
# None
# 0                    6556.515         4.0071           3.9543
# 1                    6617.483         6.3800           6.3100
# 2                    6521.634         5.7200           5.6800
# 3                    6122.663         6.4900           6.4500
# 4                    5793.069         9.2800           9.2200
# 5                    5500.281         8.3500           8.3100
# 6                    6551.608         0.9271           0.9143
# 7                    6564.670         1.1271           1.1129
# 8                    6556.515         1.0200           1.0086
# 9                    6591.004         2.0043           1.9814
# 10                   6614.251         1.7786           1.7571
# 11                   6629.413         1.3457           1.3314
# 12                   6617.483         1.2514           1.2400
# 13                   6630.519         1.9900           1.9729
# 14                   6622.245         1.4514           1.4414
# 15                   6469.854         1.0700           1.0700
# 16                   6521.634         1.2086           1.1957
# 17                   6310.161         2.0800           2.0700
# 18                   6156.699         1.6700           1.6600
# 19                   6051.711         1.2900           1.2800
# 20                   6122.663         1.4500           1.4400
# 21                   5881.803         3.0800           3.0600
# 22                   5834.858         2.3400           2.3300
# 23                   5773.099         1.8600           1.8500
# 24                   5793.069         2.0000           1.9800
# 25                   5594.127         3.3000           3.2800
# 26                   5540.886         1.9100           1.9000
# 27                   5472.781         1.4300           1.4200
# 28                   5500.281         1.7100           1.7100
# 29                   5327.995         3.3800           3.3600
# ...                       ...            ...              ...
# 940                  4419.000         7.3700           7.3700
# 941                  4282.000         7.6000           7.6000
# 942                  4196.000         3.8500           3.8500
# 943                  4177.000         1.8800           1.8800
# 944                  4971.000         2.1400           2.1400
# 945                  4912.000         2.1900           2.1800
# 946                  4843.000         2.1300           2.1300
# 947                  4875.000         1.9700           1.9700
# 948                  4716.000         2.0000           2.0000
# 949                  4657.000         3.4100           3.4100
# 950                  4597.000         2.0900           2.0900
# 951                  4628.000         2.2000           2.2000
# 952                  4485.000         2.1200           2.1200
# 953                  4433.000         1.5500           1.5500
# 954                  4395.000         1.7900           1.7900
# 955                  4419.000         1.9100           1.9100
# 956                  4328.000         2.1000           2.1000
# 957                  4297.000         2.0500           2.0500
# 958                  4267.000         1.8900           1.8900
# 959                  4282.000         1.5600           1.5600
# 960                  4211.000         1.1700           1.1700
# 961                  4200.000         1.0000           1.0000
# 962                  4190.000         1.0100           1.0100
# 963                  4196.000         0.6700           0.6700
# 964                  4178.000         0.4300           0.4300
# 965                  4178.000         0.4100           0.4100
# 966                  4178.000         0.6300           0.6300
# 967                  4177.000         0.4100           0.4100
# 968                  4223.000         0.9500           0.9500
# 969                  4271.000         0.7800           0.7800
#
# [970 rows x 249 columns]

# %% [markdown]
# This will retrieve multiple pages of data and merge them together as if they were one large page. In some cases, however, you will still exceed the request limit. In this case we recommend you filter your data using the available query parameters, as in the following example:

# %%
import quandl
data5 = quandl.get_table('ZACKS/FC', paginate=True, ticker=['AAPL', 'MSFT'], per_end_date={'gte': '2015-01-01'}, qopts={'columns':['ticker', 'per_end_date']})

# %%
data5
# Out:
#      ticker per_end_date
# None
# 0      AAPL   2015-09-30
# 1      AAPL   2016-09-30
# 2      AAPL   2015-03-31
# 3      AAPL   2015-06-30
# 4      AAPL   2015-09-30
# 5      AAPL   2015-12-31
# 6      AAPL   2016-03-31
# 7      AAPL   2016-06-30
# 8      AAPL   2016-09-30
# 9      AAPL   2016-12-31
# 10     AAPL   2017-03-31
# 11     AAPL   2017-06-30
# 12     MSFT   2015-06-30
# 13     MSFT   2016-06-30
# 14     MSFT   2017-06-30
# 15     MSFT   2015-03-31
# 16     MSFT   2015-06-30
# 17     MSFT   2015-09-30
# 18     MSFT   2015-12-31
# 19     MSFT   2016-03-31
# 20     MSFT   2016-06-30
# 21     MSFT   2016-09-30
# 22     MSFT   2016-12-31
# 23     MSFT   2017-03-31
# 24     MSFT   2017-06-30

# %% [markdown]
# In this query we are asking for more pages of data, ticker values of either AAPL or MSFT and a per_end_date that is greater than or equal to 2015-01-01. We are also filtering the returned columns on ticker, per_end_date and comp_name rather than all available columns. The output format is pandas.

# %% [markdown]
# # Load Quandl Data Directly Into Python

# %% [markdown]
# All datasets and databases on Quandl are available directly in Python, using the Quandl Python module.

# %% [markdown]
# For example: https://www.quandl.com/data/UTOR/EXTUR_ESP-Outbound-Tourism-Spain

# %% [markdown]
# Get from Export Data option - Phyton librarySign in Quandl. You must sign in.

# %%
data6 = quandl.get("UTOR/EXTUR_ESP", authtoken="wagAy5tFsmUZ84CH3Ng8")

# %%
data6.head()
# Out:
#             Departures - Thousands  \
# Date
# 1995-12-31                  3648.0
# 1996-12-31                  4224.0
# 1997-12-31                  3980.0
# 1998-12-31                  4794.0
# 1999-12-31                  3519.0
#
#             Tourism expenditure in other countries - US$ Mn  Travel - US$ Mn  \
# Date
# 1995-12-31                                           5826.0           4539.0
# 1996-12-31                                           6332.0           5057.0
# 1997-12-31                                           6163.0           4681.0
# 1998-12-31                                           7119.0           5288.0
# 1999-12-31                                           7803.0           5862.0
#
#             Passenger transport - US$ Mn
# Date
# 1995-12-31                        1287.0
# 1996-12-31                        1275.0
# 1997-12-31                        1482.0
# 1998-12-31                        1831.0
# 1999-12-31                        1941.0

# %% [markdown]
# # 5 - Regression model with Statsmodels and without a constant

# %%
import statsmodels.api as sm

X = data6["Departures - Thousands"]
y = data6["Travel - US$ Mn"]

# %% [markdown]
# Note the difference in argument order:

# %%
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)

# %% [markdown]
# Make the predictions by the model:

# %%
predictions = model.predict(X)

# %% [markdown]
# Print out the statistics:

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Travel - US$ Mn   R-squared:                       0.976
# Model:                            OLS   Adj. R-squared:                  0.975
# Method:                 Least Squares   F-statistic:                     784.6
# Date:                Tue, 03 Oct 2017   Prob (F-statistic):           6.48e-17
# Time:                        19:53:37   Log-Likelihood:                -180.83
# No. Observations:                  20   AIC:                             363.7
# Df Residuals:                      19   BIC:                             364.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Departures - Thousands     1.4936      0.053     28.011      0.000         1.382     1.605
# ==============================================================================
# Omnibus:                        1.502   Durbin-Watson:                   0.912
# Prob(Omnibus):                  0.472   Jarque-Bera (JB):                1.247
# Skew:                           0.560   Prob(JB):                        0.536
# Kurtosis:                       2.510   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Interpreting the Table

# %% [markdown]
# The coefficient of 1.4936 means that as the Departures - Thousands variable increases by 1, the predicted value of Travel - US$ Mn increases by 1.4936. A few other important values are the R-squared of 0.976 — the percentage of variance our model explains.

# %% [markdown]
# # 6 - Regression model with Statsmodels and with a constant

# %%
import statsmodels.api as sm

X = data6["Departures - Thousands"]
y = data6["Travel - US$ Mn"]

# %%
X = sm.add_constant(X)

# %%
model = sm.OLS(y, X).fit() ## sm.OLS(output, input)

# %%
predictions = model.predict(X)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        Travel - US$ Mn   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.870
# Method:                 Least Squares   F-statistic:                     128.4
# Date:                Tue, 03 Oct 2017   Prob (F-statistic):           1.26e-09
# Time:                        19:53:45   Log-Likelihood:                -180.42
# No. Observations:                  20   AIC:                             364.8
# Df Residuals:                      18   BIC:                             366.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# const                    939.2279   1084.358      0.866      0.398     -1338.923  3217.379
# Departures - Thousands     1.3975      0.123     11.332      0.000         1.138     1.657
# ==============================================================================
# Omnibus:                        2.126   Durbin-Watson:                   0.871
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.741
# Skew:                           0.673   Prob(JB):                        0.419
# Kurtosis:                       2.475   Cond. No.                     2.02e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.02e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Interpreting the Table
# With the constant term the coefficients are different. Without a constant we are forcing our model to go through the origin, but now we have a y-intercept at 939.2279. We also changed the slope of the Departures - Thousands predictor from 1.4936 to 1.3975.
# A few other important values are modification of the R-squared, from 0.976 to 0.877.
